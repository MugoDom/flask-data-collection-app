# %% [markdown]
# We explore the collected data from the survey form

# %%
# Load the libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load the Data

# %%
survey_data = pd.read_csv("../data/user_data.csv")
survey_data.head()
# Out:
#    age  gender   income  expense_utilities  expense_entertainment  \
# 0   20    male   2000.0             1000.0                  500.0
# 1   54    male   7000.0             1000.0                  500.0
# 2   23  female  20000.0            10000.0                 5000.0
# 3   32   other   1345.0              100.0                  200.0
# 4   44    male   7568.0              500.0                  100.0
#
#    expense_school_fees  expense_shopping  expense_healthcare
# 0                  0.0             500.0                 0.0
# 1               1000.0             500.0              1000.0
# 2                  0.0            1000.0              1000.0
# 3                  0.0             300.0                20.0
# 4               1345.0            1200.0                 0.0

# %% [markdown]
# ##### Data Visualization

# %% [markdown]
# Show the ages with the highest income.

# %%
income_df = survey_data[['age', 'income']]

#Sort the data by income in descending order to get highest incomes
df_sorted = income_df.sort_values(by='income', ascending=False)


top_ages_by_income = df_sorted.head(10)

#Plot the data
plt.figure(figsize=(10, 6))
plt.bar(top_ages_by_income['age'], top_ages_by_income['income'], color='skyblue')
plt.xlabel('Age')
plt.ylabel('Income ($)')
plt.title('Top 10 Ages with Highest Income')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Export chart
plt.savefig('charts/top_ages_by_income.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Export chart
# ----> 2 plt.savefig('charts/top_ages_by_income.png', dpi=300)
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/venv/lib/python3.9/site-packages/PIL/Image.py:2600, in Image.save(self, fp, format, **params)
#    2598         fp = builtins.open(filename, "r+b")
#    2599     else:
# -> 2600         fp = builtins.open(filename, "w+b")
#    2601 else:
#    2602     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/dominic/Downloads/Nexford_University/Programming_in_R_and_Python/final_project/flask-data-collection-app/notebooks/charts/top_ages_by_income.png'

# %% [markdown]
# Show the gender distribution across spending categories.

# %% [markdown]
# ##### Exporting the data

# %% [markdown]
# Export the charts for use in a PowerPoint presentation for client use
